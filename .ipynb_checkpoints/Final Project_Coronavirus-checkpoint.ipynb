# %%
import numpy as np 
import pandas as pd 
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
from plotly.offline import init_notebook_mode, iplot 
import plotly.graph_objs as go
import plotly.offline as py
import pycountry
py.init_notebook_mode(connected=True)
import folium 
from folium import plugins

# %config InlineBackend.figure_format = 'retina' 

plt.rcParams['figure.figsize'] = 8, 5

import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# data_corona= pd.read_csv("Coronavirus_data.csv",)
data_corona= pd.read_csv("updated_2019_nCoV_data.csv",)
data_corona.head()
# Out:
#   Province/State Country      Last Update  Confirmed  Deaths  Recovered
# 0          Anhui   China  1/22/2020 12:00          1       0          0
# 1        Beijing   China  1/22/2020 12:00         14       0          0
# 2      Chongqing   China  1/22/2020 12:00          6       0          0
# 3         Fujian   China  1/22/2020 12:00          1       0          0
# 4          Gansu   China  1/22/2020 12:00          0       0          0

# %%
data_corona['Last Update'] = data_corona['Last Update'].apply(pd.to_datetime)
data_corona.head()
# Out:
#   Province/State Country         Last Update  Confirmed  Deaths  Recovered
# 0          Anhui   China 2020-01-22 12:00:00          1       0          0
# 1        Beijing   China 2020-01-22 12:00:00         14       0          0
# 2      Chongqing   China 2020-01-22 12:00:00          6       0          0
# 3         Fujian   China 2020-01-22 12:00:00          1       0          0
# 4          Gansu   China 2020-01-22 12:00:00          0       0          0

# %%
countries_corona = data_corona['Country'].unique().tolist()
print(countries_corona)
# Out:
# ['China', 'US', 'Japan', 'Thailand', 'South Korea', 'Mainland China', 'Hong Kong', 'Macau', 'Taiwan', 'Singapore', 'Philippines', 'Malaysia', 'Vietnam', 'Australia', 'Mexico', 'Brazil', 'France', 'Nepal', 'Canada', 'Cambodia', 'Sri Lanka', 'Ivory Coast', 'Germany', 'Finland', 'United Arab Emirates', 'India', 'Italy', 'Sweden', 'Russia', 'Spain', 'UK', 'Belgium']

# %%
print(f"Total countries affected by Coronavirus: {len(countries_corona)}")
# Out:
# Total countries affected by Coronavirus: 32

# %%
from datetime import date
data_date_corona = data_corona[data_corona['Last Update'] > pd.Timestamp(date(2020,1,2))]

data_date_corona.head()
# Out:
#   Province/State Country         Last Update  Confirmed  Deaths  Recovered
# 0          Anhui   China 2020-01-22 12:00:00          1       0          0
# 1        Beijing   China 2020-01-22 12:00:00         14       0          0
# 2      Chongqing   China 2020-01-22 12:00:00          6       0          0
# 3         Fujian   China 2020-01-22 12:00:00          1       0          0
# 4          Gansu   China 2020-01-22 12:00:00          0       0          0

# %%
data_date_corona.dtypes
# Out:
# Province/State            object
# Country                   object
# Last Update       datetime64[ns]
# Confirmed                  int64
# Deaths                     int64
# Recovered                  int64
# dtype: object

# %%
cases_corona = pd.DataFrame(data_date_corona.groupby('Country')['Confirmed'].sum())
cases_corona['Country'] = cases_corona.index
cases_corona.index=np.arange(1,33)
cases_corona
# Out:
#     Confirmed               Country
# 1         194             Australia
# 2           8               Belgium
# 3           0                Brazil
# 4          16              Cambodia
# 5          73                Canada
# 6         549                 China
# 7          14               Finland
# 8         117                France
# 9         156               Germany
# 10        349             Hong Kong
# 11         32                 India
# 12         31                 Italy
# 13          0           Ivory Coast
# 14        672                 Japan
# 15        149                 Macau
# 16     371856        Mainland China
# 17        181              Malaysia
# 18          0                Mexico
# 19         18                 Nepal
# 20         29           Philippines
# 21         24                Russia
# 22        398             Singapore
# 23        273           South Korea
# 24         15                 Spain
# 25         16             Sri Lanka
# 26         12                Sweden
# 27        206                Taiwan
# 28        380              Thailand
# 29         39                    UK
# 30        162                    US
# 31         76  United Arab Emirates
# 32        130               Vietnam

# %%
global_cases_corona = cases_corona[['Country','Confirmed']]
global_cases_corona
# Out:
#                  Country  Confirmed
# 1              Australia        194
# 2                Belgium          8
# 3                 Brazil          0
# 4               Cambodia         16
# 5                 Canada         73
# 6                  China        549
# 7                Finland         14
# 8                 France        117
# 9                Germany        156
# 10             Hong Kong        349
# 11                 India         32
# 12                 Italy         31
# 13           Ivory Coast          0
# 14                 Japan        672
# 15                 Macau        149
# 16        Mainland China     371856
# 17              Malaysia        181
# 18                Mexico          0
# 19                 Nepal         18
# 20           Philippines         29
# 21                Russia         24
# 22             Singapore        398
# 23           South Korea        273
# 24                 Spain         15
# 25             Sri Lanka         16
# 26                Sweden         12
# 27                Taiwan        206
# 28              Thailand        380
# 29                    UK         39
# 30                    US        162
# 31  United Arab Emirates         76
# 32               Vietnam        130

# %%
world_data = pd.DataFrame({
   'name':list(global_cases_corona['Country']),
    'lat':[-25.2744,50.5039,-23.533773,11.5564,56.1304,35.8617,61.9241,46.2276,51.1657,22.3193,20.5937,41.8719,7.5400,36.2048,22.1987,35,4.2105,23.6345,28.3949,12.8797,55.7558,1.3521,35.9078,40.4637,7.8731,60.1282,23.6978,15.8700,51.5074,37.0902,23.4241,14.0583],
   'lon':[133.7751,4.4699,-46.625290,104.9282,-106.3468,104.1954,25.7482,2.2137,10.4515,114.1694,78.9629,12.5674,5.5471,138.2529,113.5439,105,101.9758,102.5528,84.1240,121.7740,37.6173,103.8198,127.7669,3.7492,80.7718,18.6435,120.9605,100.9925,0.1278,-95.7129,53.8478,108.2772],
   'Confirmed':list(global_cases_corona['Confirmed']),
})


world_map = folium.Map(location=[10, -20], zoom_start=2.3,tiles='Stamen Toner')

for lat, lon, value, name in zip(world_data['lat'], world_data['lon'], world_data['Confirmed'], world_data['name']):
    folium.CircleMarker([lat, lon],
                        radius=10,
                        popup = ('<strong>Country</strong>: ' + str(name).capitalize() + '<br>'
                                '<strong>Confirmed Cases on January 30, 2020</strong>: ' + str(value) + '<br>'),
                        color='red',
                        
                        fill_color='red',
                        fill_opacity=0.7 ).add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# world_data = pd.DataFrame({
#    'name':list(global_cases_corona['Country']),
#     'lat':[-25.27,12.57,56.13,61.92,46.23,51.17,22.32,20.59,41.87,36.2,22.2,35.86,4.21,28.39,12.87,1.35,35.91,7.87,23.7,15.87,37.09,23.42,14.06,],
#    'lon':[133.78,104.99,-106.35,25.75,2.21,10.45,114.17,78.96,12.56,138.25,113.54,104.19,101.98,84.12,121.77,103.82,127.77,80.77,120.96,100.99,-95.71,53.84,108.28],
#    'Confirmed':list(global_cases_corona['Confirmed']),
# })


# world_map = folium.Map(location=[10, -20], zoom_start=2.3,tiles='Stamen Toner')

# for lat, lon, value, name in zip(world_data['lat'], world_data['lon'], world_data['Confirmed'], world_data['name']):
#     folium.CircleMarker([lat, lon],
#                         radius=10,
#                         popup = ('<strong>Country</strong>: ' + str(name).capitalize() + '<br>'
#                                 '<strong>Confirmed Cases on January 30, 2020</strong>: ' + str(value) + '<br>'),
#                         color='red',
                        
#                         fill_color='red',
#                         fill_opacity=0.7 ).add_to(world_map)
# world_map

# %%
print(f"Globally Confirmed Corona Cases: {data_date_corona['Confirmed'].sum()}")
print(f"Globally Confirmed Corona Deaths: {data_date_corona['Deaths'].sum()}")
print(f"Globally Confirmed Corona Recovered: {data_date_corona['Recovered'].sum()}")
# Out:
# Globally Confirmed Corona Cases: 376175
# Globally Confirmed Corona Deaths: 8263
# Globally Confirmed Corona Recovered: 22307

# %%
data_date_corona.groupby(['Country','Province/State']).sum()
# Out:
#                                 Confirmed  Deaths  Recovered
# Country   Province/State
# Australia New South Wales              64       0         26
#           Queensland                   48       0          0
#           South Australia              22       0          0
#           Victoria                     52       0          0
# Canada    British Columbia             31       0          0
# ...                                   ...     ...        ...
# US        San Diego County, CA          1       0          0
#           Santa Clara, CA              21       0          0
#           Seattle, WA                  11       0          3
#           Tempe, AZ                    11       0          0
#           Washington                   10       0          0
#
# [93 rows x 3 columns]

# %%
data_date_corona.groupby('Country')['Deaths'].sum().sort_values(ascending=False)[:5]
# Out:
# Country
# Mainland China    8244
# Philippines         11
# Hong Kong            8
# Macau                0
# Belgium              0
# Name: Deaths, dtype: int64

# %%
data_date_corona.groupby('Country')['Recovered'].sum().sort_values(ascending=False)[:5]
# Out:
# Country
# Mainland China    22073
# Thailand            101
# Japan                28
# Australia            26
# Vietnam              16
# Name: Recovered, dtype: int64

# %%
China = data_date_corona[data_date_corona['Country']=='Mainland China']
China
# Out:
#       Province/State         Country         Last Update  Confirmed  Deaths  \
# 38             Anhui  Mainland China 2020-01-23 12:00:00          9       0
# 39           Beijing  Mainland China 2020-01-23 12:00:00         22       0
# 40         Chongqing  Mainland China 2020-01-23 12:00:00          9       0
# 41            Fujian  Mainland China 2020-01-23 12:00:00          5       0
# 42             Gansu  Mainland China 2020-01-23 12:00:00          2       0
# ...              ...             ...                 ...        ...     ...
# 1224        Xinjiang  Mainland China 2020-02-12 01:43:00         59       0
# 1225  Inner Mongolia  Mainland China 2020-02-10 02:43:00         58       0
# 1226         Ningxia  Mainland China 2020-02-11 10:03:00         53       0
# 1232         Qinghai  Mainland China 2020-02-11 11:23:00         18       0
# 1259           Tibet  Mainland China 2020-02-01 01:52:00          1       0
#
#       Recovered
# 38            0
# 39            0
# 40            0
# 41            0
# 42            0
# ...         ...
# 1224          3
# 1225          5
# 1226         22
# 1232          5
# 1259          0
#
# [615 rows x 6 columns]

# %%
f, ax = plt.subplots(figsize=(12, 8))

sns.set_color_codes("pastel")
sns.barplot(x="Confirmed", y="Province/State", data=China[1:],
            label="Confirmed", color="r")

sns.set_color_codes("muted")
sns.barplot(x="Recovered", y="Province/State", data=China[1:],
            label="Recovered", color="g")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Stats")
sns.despine(left=True, bottom=True)
